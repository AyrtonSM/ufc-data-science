# %%
import pandas as pd

# %%
food_inspect = pd.read_csv('Food_Inspections_-_Map.csv')

# %%
food_inspect.set_index('DBA Name')
# Out:
#                                                                                     AKA Name  \
# DBA Name
# DANY'S TACOS                                                                    DANY'S TACOS
# BILLY FOOD MARKET INC                                                      BILLY FOOD MARKET
# TAQUERIA HACIENDA TAPATIA                                          TAQUERIA HACIENDA TAPATIA
# WILD GOOSE BAR & GRILL                                                WILD GOOSE BAR & GRILL
# PUBLICAN TAVERN K1                                              PUBLICAN TAVERN K1 (T3 MAIN)
# LABRIOLA BAKERY AND CAFE                                                                 NaN
# PARK  PLAZA RETIREMENT CENTER                                                     PARK PLAZA
# SULLIVAN'S STEAKHOUSE                                                  SULLIVAN'S STEAKHOUSE
# THRESHOLD SCHOOL                                                            THRESHOLD SCHOOL
# ...

# %%
food_inspect['Risk']
# Out:
# 0           Risk 1 (High)
# 1            Risk 3 (Low)
# 2           Risk 1 (High)
# 3           Risk 1 (High)
# 4           Risk 1 (High)
# 5         Risk 2 (Medium)
# 6           Risk 1 (High)
# 7           Risk 1 (High)
# 8           Risk 1 (High)
# 9           Risk 1 (High)
# 10          Risk 1 (High)
# 11          Risk 1 (High)
# 12          Risk 1 (High)
# 13          Risk 1 (High)
# 14        Risk 2 (Medium)
# 15          Risk 1 (High)
# 16          Risk 1 (High)
# 17          Risk 1 (High)
# 18        Risk 2 (Medium)
# 19          Risk 1 (High)
# 20          Risk 1 (High)
# 21        Risk 2 (Medium)
# 22          Risk 1 (High)
# 23          Risk 1 (High)
# 24          Risk 1 (High)
# 25          Risk 1 (High)
# 26        Risk 2 (Medium)
# 27        Risk 2 (Medium)
# 28          Risk 1 (High)
# 29          Risk 1 (High)
#                ...
# 146047       Risk 3 (Low)
# 146048      Risk 1 (High)
# 146049       Risk 3 (Low)
# 146050       Risk 3 (Low)
# ...

# %%
food_inspect[['Risk','Results']]
# Out:
#                    Risk             Results
# 0         Risk 1 (High)                Fail
# 1          Risk 3 (Low)           Not Ready
# 2         Risk 1 (High)                Pass
# 3         Risk 1 (High)                Fail
# 4         Risk 1 (High)                Fail
# 5       Risk 2 (Medium)           Not Ready
# 6         Risk 1 (High)                Fail
# 7         Risk 1 (High)                Fail
# 8         Risk 1 (High)                Pass
# 9         Risk 1 (High)  Pass w/ Conditions
# 10        Risk 1 (High)                Fail
# 11        Risk 1 (High)                Pass
# 12        Risk 1 (High)  Pass w/ Conditions
# 13        Risk 1 (High)                Pass
# 14      Risk 2 (Medium)                Pass
# 15        Risk 1 (High)                Pass
# 16        Risk 1 (High)                Fail
# 17        Risk 1 (High)                Pass
# 18      Risk 2 (Medium)     Out of Business
# 19        Risk 1 (High)                Fail
# ...

# %%
food_inspect[['Facility Type']]
# Out:
#                           Facility Type
# 0                            Restaurant
# 1                                   NaN
# 2                            Restaurant
# 3                            Restaurant
# 4                            Restaurant
# 5                                Bakery
# 6                            Restaurant
# 7                            Restaurant
# 8                                School
# 9                            Restaurant
# 10                           Restaurant
# 11                           Restaurant
# 12                           Restaurant
# 13                               School
# 14                           Restaurant
# 15                               School
# 16                           Restaurant
# 17                           Restaurant
# 18                        Grocery Store
# 19                           Restaurant
# 20                           Restaurant
# 21                        Grocery Store
# ...

# %%
food_inspect = food_inspect.set_index('DBA Name')

# %%
food_inspect.loc['SCRUB A DUB', 'Risk']
# Out:
# 'Risk 2 (Medium)'

# %%
#food_inspect.loc['THRESHOLD SCHOOL':'SCRUB A DUB':3000,'Inspection Type':]

# %%
food_inspect.iloc[500:510]
# Out:
#                                                   AKA Name  License #  \
# DBA Name
# PENINSULA CHICAGO,LLC                         MAIN KITCHEN  1091966.0
# VENEZUELAN BOWL GRILL LLC            VENEZUELAN BOWL GRILL  2424110.0
# JULIUS MEINL                                  JULIUS MEINL  2141409.0
# MEZQUITE EXPRESS # 2                  MEZQUITE EXPRESS # 2  2517585.0
# PORTILLO'S HOT DOGS                    PORTILLO'S HOT DOGS    39472.0
# SEE THRU CHINESE RESTAURANT    SEE THRU CHINESE RESTAURANT  1942299.0
# DENOVA FRESH MARKET                   MARTHA'S FOOD MARKET  2517805.0
# SOUTH LOOP MONTESSORI SCHOOL  SOUTH LOOP MONTESSORI SCHOOL  2517217.0
# LORETTO HOSPITAL                          LORETTO HOSPITAL  2204616.0
# MONTROSE DELI & FRUIT MARKET  MONTROSE DELI & FRUIT MARKET    20886.0
#
#                                       Facility Type           Risk  \
# DBA Name
# PENINSULA CHICAGO,LLC                    Restaurant  Risk 1 (High)
# ...

# %%
food_inspect.iloc[[100, 1000, 10000], [5, 3, 1]]
# Out:
#                    City           Risk  License #
# DBA Name
# A-Z SALES INC.  CHICAGO  Risk 1 (High)  1490343.0
# ANONG INC.      CHICAGO  Risk 1 (High)  1942424.0
# ELVIA GAMA      CHICAGO  Risk 1 (High)  2423902.0

# %%
risk = food_inspect.loc[:,'Risk']
risk.head()
# Out:
# DBA Name
# DANY'S TACOS                 Risk 1 (High)
# BILLY FOOD MARKET INC         Risk 3 (Low)
# TAQUERIA HACIENDA TAPATIA    Risk 1 (High)
# WILD GOOSE BAR & GRILL       Risk 1 (High)
# PUBLICAN TAVERN K1           Risk 1 (High)
# Name: Risk, dtype: object

# %%
risk.loc[['ARBYS', 'POPEYES FAMOUS FRIED CHICKEN']]
# Out:
# DBA Name
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ARBYS                             Risk 1 (High)
# ...
