# %%
import pandas as pd

# %%
df = pd.read_csv('employee.csv')

# %%
df['DEPARTMENT'].value_counts()
# Out:
# Houston Police Department-HPD     638
# Houston Fire Department (HFD)     384
# Public Works & Engineering-PWE    343
# Health & Human Services           110
# Houston Airport System (HAS)      106
# Parks & Recreation                 74
# Solid Waste Management             43
# Library                            36
# Fleet Management Department        36
# Admn. & Regulatory Affairs         29
# Municipal Courts Department        28
# Human Resources Dept.              24
# Houston Emergency Center (HEC)     23
# General Services Department        22
# Housing and Community Devp.        22
# Legal Department                   17
# Dept of Neighborhoods (DON)        17
# City Council                       11
# Finance                            10
# Houston Information Tech Svcs       9
# Planning & Development              7
# Mayor's Office                      5
# City Controller's Office            5
# Convention and Entertainment        1
# Name: DEPARTMENT, dtype: int64

# %%
df['BASE_SALARY'].sum()
# Out:
# 105178319.0

# %%
df['BASE_SALARY'].min()
# Out:
# 24960.0

# %%
df['BASE_SALARY'].max()
# Out:
# 275000.0

# %%
df['BASE_SALARY'].mean()
# Out:
# 55767.93160127253

# %%
df['BASE_SALARY'].std()
# Out:
# 21693.706679449504

# %%
df['BASE_SALARY'].var()
# Out:
# 470616909.49399203

# %%
s = df['BASE_SALARY'].apply(lambda v : 0.1 * v)
s.head()
# Out:
# 0    12186.2
# 1     2612.5
# 2     4527.9
# 3     6316.6
# 4     5634.7
# Name: BASE_SALARY, dtype: float64

# %%
df['BASE_SALARY'].count()
# Out:
# 1886

# %%
base_salary =  df['BASE_SALARY'].fillna(1000.0)

# %%
bs = df['BASE_SALARY'].dropna()

# %%
bs.count()
# Out:
# 1886

# %%
gb = df.groupby('DEPARTMENT').count()
gb.head()
# Out:
#                               POSITION_TITLE  BASE_SALARY  RACE  \
# DEPARTMENT
# Admn. & Regulatory Affairs                29           29    26
# City Controller's Office                   5            5     5
# City Council                              11            9     9
# Convention and Entertainment               1            1     1
# Dept of Neighborhoods (DON)               17           17    17
#
#                               EMPLOYMENT_TYPE  GENDER  HIRE_DATE  JOB_DATE
# DEPARTMENT
# Admn. & Regulatory Affairs                 29      29         29        28
# City Controller's Office                    5       5          5         5
# City Council                               11      11         11        11
# Convention and Entertainment                1       1          1         1
# Dept of Neighborhoods (DON)                17      17         17        17

# %%
gb = df.groupby('DEPARTMENT')[['GENDER','RACE']].count()
gb.head()
# Out:
#                               GENDER  RACE
# DEPARTMENT
# Admn. & Regulatory Affairs        29    26
# City Controller's Office           5     5
# City Council                      11     9
# Convention and Entertainment       1     1
# Dept of Neighborhoods (DON)       17    17

# %%
gb = df.groupby(['DEPARTMENT','RACE'])['BASE_SALARY'].mean()
gb.loc[('Library','Black or African American')].mean()
# Out:
# 46305.916666666664

# %%
gb = df.groupby(['DEPARTMENT','RACE'])['BASE_SALARY'].apply(lambda s : s.mean())
gb
# Out:
# DEPARTMENT                      RACE
# Admn. & Regulatory Affairs      Asian/Pacific Islander                72293.666667
#                                 Black or African American             46410.833333
#                                 Hispanic/Latino                       36400.000000
#                                 White                                 77437.200000
# City Controller's Office        Asian/Pacific Islander                59077.000000
#                                 Black or African American             51743.333333
#                                 Hispanic/Latino                       64251.000000
# City Council                    Black or African American             77000.000000
#                                 Hispanic/Latino                       35837.000000
#                                 White                                 64241.500000
# Convention and Entertainment    Hispanic/Latino                       38397.000000
# Dept of Neighborhoods (DON)     American Indian or Alaskan Native     26125.000000
#                                 Black or African American             48724.700000
#                                 Hispanic/Latino                       44275.000000
#                                 White                                 65832.000000
# Finance                         Black or African American             78560.800000
#                                 Hispanic/Latino                       82799.750000
# Fleet Management Department     Asian/Pacific Islander                46010.000000
#                                 Black or African American             40245.000000
#                                 Hispanic/Latino                       42667.666667
#                                 White                                 52944.400000
# General Services Department     Black or African American             28741.600000
#                                 Hispanic/Latino                       49269.300000
#                                 White                                 70301.000000
# Health & Human Services         American Indian or Alaskan Native     54117.000000
#                                 Asian/Pacific Islander                55357.909091
#                                 Black or African American             55905.117647
#                                 Hispanic/Latino                       36223.851852
#                                 Others                                51278.000000
#                                 White                                 61674.750000
#                                                                          ...
# Legal Department                White                                 96793.125000
# Library                         American Indian or Alaskan Native     26125.000000
#                                 Asian/Pacific Islander                37440.000000
#                                 Black or African American             46305.916667
#                                 Hispanic/Latino                       46777.750000
#                                 White                                 43886.000000
# Mayor's Office                  Asian/Pacific Islander                60925.000000
#                                 Black or African American             44990.000000
#                                 Hispanic/Latino                       95783.000000
#                                 White                                115375.000000
# Municipal Courts Department     Asian/Pacific Islander                         NaN
#                                 Black or African American             45469.933333
#                                 Hispanic/Latino                       52782.500000
#                                 White                                 79727.200000
# Parks & Recreation              Asian/Pacific Islander                48651.000000
#                                 Black or African American             36815.750000
#                                 Hispanic/Latino                       41315.625000
#                                 White                                 43630.500000
# Planning & Development          Asian/Pacific Islander                65402.000000
#                                 Black or African American             68762.000000
#                                 Hispanic/Latino                       47098.333333
#                                 White                                 54349.000000
# Public Works & Engineering-PWE  Asian/Pacific Islander                66915.620690
#                                 Black or African American             42486.888235
#                                 Hispanic/Latino                       45502.838235
#                                 White                                 65720.878378
# Solid Waste Management          Asian/Pacific Islander                37898.000000
#                                 Black or African American             40849.777778
#                                 Hispanic/Latino                       44334.700000
#                                 White                                 77966.000000
# Name: BASE_SALARY, Length: 94, dtype: float64

# %%
sd = pd.read_csv('sample_data.csv', index_col=0)

# %%
sd
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %%
sd.sort_values('age',ascending=False)
# Out:
#           state  color    food  age  height  score
# Cornelia     TX    red   Beans   69     150    2.2
# Christina    TX  black   Melon   33     172    9.5
# Dean         AK   gray  Cheese   32     180    1.8
# Jane         NY   blue   Steak   30     165    4.6
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Niko         TX  green    Lamb    2      70    8.3

# %%
sd.sort_index()
# Out:
#           state  color    food  age  height  score
# Aaron        FL    red   Mango   12     120    9.0
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2
# Dean         AK   gray  Cheese   32     180    1.8
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Penelope     AL  white   Apple    4      80    3.3

# %%
sd.index.name = "names"

# %%
sd
# Out:
#           state  color    food  age  height  score
# names
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %%
sd.reset_index()
# Out:
#        names state  color    food  age  height  score
# 0       Jane    NY   blue   Steak   30     165    4.6
# 1       Niko    TX  green    Lamb    2      70    8.3
# 2      Aaron    FL    red   Mango   12     120    9.0
# 3   Penelope    AL  white   Apple    4      80    3.3
# 4       Dean    AK   gray  Cheese   32     180    1.8
# 5  Christina    TX  black   Melon   33     172    9.5
# 6   Cornelia    TX    red   Beans   69     150    2.2

# %%
sd.drop(columns=["age","food"])
# Out:
#           state  color  height  score
# names
# Jane         NY   blue     165    4.6
# Niko         TX  green      70    8.3
# Aaron        FL    red     120    9.0
# Penelope     AL  white      80    3.3
# Dean         AK   gray     180    1.8
# Christina    TX  black     172    9.5
# Cornelia     TX    red     150    2.2

# %%
sd.drop(index=['Niko','Penelope'])
# Out:
#           state  color    food  age  height  score
# names
# Jane         NY   blue   Steak   30     165    4.6
# Aaron        FL    red   Mango   12     120    9.0
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %%
pd.pivot_table(df, values='BASE_SALARY',index='DEPARTMENT',columns='RACE', aggfunc='mean')
# Out:
# RACE                            American Indian or Alaskan Native  \
# DEPARTMENT
# Admn. & Regulatory Affairs                                    NaN
# City Controller's Office                                      NaN
# City Council                                                  NaN
# Convention and Entertainment                                  NaN
# Dept of Neighborhoods (DON)                          26125.000000
# Finance                                                       NaN
# Fleet Management Department                                   NaN
# General Services Department                                   NaN
# Health & Human Services                              54117.000000
# Housing and Community Devp.                          98536.000000
# Houston Airport System (HAS)                         68299.000000
# Houston Emergency Center (HEC)                                NaN
# Houston Fire Department (HFD)                        78355.000000
# Houston Information Tech Svcs                                 NaN
# Houston Police Department-HPD                        65682.333333
# Human Resources Dept.                                         NaN
# Legal Department                                              NaN
# Library                                              26125.000000
# Mayor's Office                                                NaN
# Municipal Courts Department                                   NaN
# Parks & Recreation                                            NaN
# Planning & Development                                        NaN
# Public Works & Engineering-PWE                                NaN
# Solid Waste Management                                        NaN
#
# RACE                            Asian/Pacific Islander  \
# DEPARTMENT
# Admn. & Regulatory Affairs                72293.666667
# City Controller's Office                  59077.000000
# City Council                                       NaN
# Convention and Entertainment                       NaN
# Dept of Neighborhoods (DON)                        NaN
# Finance                                            NaN
# Fleet Management Department               46010.000000
# General Services Department                        NaN
# Health & Human Services                   55357.909091
# Housing and Community Devp.               67682.000000
# Houston Airport System (HAS)              44595.833333
# Houston Emergency Center (HEC)                     NaN
# Houston Fire Department (HFD)             43528.000000
# Houston Information Tech Svcs             97755.000000
# Houston Police Department-HPD             59569.641026
# Human Resources Dept.                    110547.000000
# Legal Department                         100969.000000
# Library                                   37440.000000
# Mayor's Office                            60925.000000
# Municipal Courts Department                        NaN
# Parks & Recreation                        48651.000000
# Planning & Development                    65402.000000
# Public Works & Engineering-PWE            66915.620690
# Solid Waste Management                    37898.000000
#
# RACE                            Black or African American  Hispanic/Latino  \
# DEPARTMENT
# Admn. & Regulatory Affairs                   46410.833333     36400.000000
# City Controller's Office                     51743.333333     64251.000000
# City Council                                 77000.000000     35837.000000
# Convention and Entertainment                          NaN     38397.000000
# Dept of Neighborhoods (DON)                  48724.700000     44275.000000
# Finance                                      78560.800000     82799.750000
# Fleet Management Department                  40245.000000     42667.666667
# General Services Department                  28741.600000     49269.300000
# Health & Human Services                      55905.117647     36223.851852
# Housing and Community Devp.                  54336.181818     72283.500000
# Houston Airport System (HAS)                 51733.425000     48435.133333
# Houston Emergency Center (HEC)               45509.384615     49497.000000
# Houston Fire Department (HFD)                57950.073529     56892.051020
# Houston Information Tech Svcs                52333.000000     67878.500000
# Houston Police Department-HPD                55746.447205     58123.133803
# Human Resources Dept.                        53875.562500     38857.333333
# Legal Department                            122751.750000    105674.000000
# Library                                      46305.916667     46777.750000
# Mayor's Office                               44990.000000     95783.000000
# Municipal Courts Department                  45469.933333     52782.500000
# Parks & Recreation                           36815.750000     41315.625000
# Planning & Development                       68762.000000     47098.333333
# Public Works & Engineering-PWE               42486.888235     45502.838235
# Solid Waste Management                       40849.777778     44334.700000
#
# RACE                             Others          White
# DEPARTMENT
# Admn. & Regulatory Affairs          NaN   77437.200000
# City Controller's Office            NaN            NaN
# City Council                        NaN   64241.500000
# Convention and Entertainment        NaN            NaN
# Dept of Neighborhoods (DON)         NaN   65832.000000
# Finance                             NaN            NaN
# Fleet Management Department         NaN   52944.400000
# General Services Department         NaN   70301.000000
# Health & Human Services         51278.0   61674.750000
# Housing and Community Devp.         NaN   62897.250000
# Houston Airport System (HAS)        NaN   65490.115385
# Houston Emergency Center (HEC)      NaN   49252.666667
# Houston Fire Department (HFD)       NaN   62170.822335
# Houston Information Tech Svcs       NaN   75353.750000
# Houston Police Department-HPD       NaN   65313.151111
# Human Resources Dept.               NaN   65589.000000
# Legal Department                    NaN   96793.125000
# Library                             NaN   43886.000000
# Mayor's Office                      NaN  115375.000000
# Municipal Courts Department         NaN   79727.200000
# Parks & Recreation                  NaN   43630.500000
# Planning & Development              NaN   54349.000000
# Public Works & Engineering-PWE      NaN   65720.878378
# Solid Waste Management              NaN   77966.000000
